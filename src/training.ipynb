# %% [markdown]
# # Fastai Experimentation

# %% [markdown]
# This notebook is intended to be used after running the google image scraper in this repo. To get started follow the README.md in this repo, then come back after all the csv files have been generated, labeled, and saved in the data_csv directory.

# %%
from fastai.vision import *
import os
path = Path(f'../data_csv')

# %% [markdown]
# ### Define Experiment
# Running this cell will save the images and any saved models in a directory with the experiments name.

# %%
experiment = 'trees'

# %%
dest_path = Path(f'../data')
img_path = dest_path/experiment

# %% [markdown]
# ## Download images per class
# The google scraper will save the csv files labeled by the classes you want to train. These csv files will be nested in a directory with the labeled classname. For example:
# ```
# data_csv/
#     ash_tree/
#         ash_tree.csv
#     bigleaf_maple/
#         bigleaf_maple.csv
#         ...
# ```
# The images will be saved in a data directory nested under experiment name and class name:
# ```
# data/
#     trees/
#         ash_tree/
#             *.jpeg
# ```

# %%
for folder in os.listdir('../data_csv'):
    file = path/folder/os.listdir(f'../data_csv/{folder}')[0]
    dest = img_path/folder
    dest.mkdir(parents=True, exist_ok=True)
    print(folder, '   ',file, ' dest', dest)
    download_images(file, dest, max_pics=200)

# %% [markdown]
# ## Verify Images can be Trained

# %%
classes = os.listdir(f'../data/{experiment}')
for c in classes:
    print(c)
    verify_images(img_path/c, delete=True, max_size=500)

# %% [markdown]
# ## Create ImageDataBunch for Training

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(img_path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# ## Show Classes to be Trained

# %%
data.classes
# Out:
# ['Douglas-fir',
#  'Oregon_white_oak',
#  'Pacific_madrone',
#  'Pacific_willow',
#  'Pacific_yew',
#  'Ponderosa_pine',
#  'Scouler_willow',
#  'Western_flowering_dogwood',
#  'Western_hemlock',
#  'Western_red_cedar',
#  'ash_tree',
#  'bigleaf_maple',
#  'bitter_cherry',
#  'black_cottonwood',
#  'black_hawthorn',
#  'cascara',
#  'grand_fir',
#  'quaking_aspen',
#  'red_alder',
#  'rigid_willow']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Douglas-fir',
#   'Oregon_white_oak',
#   'Pacific_madrone',
#   'Pacific_willow',
#   'Pacific_yew',
#   'Ponderosa_pine',
#   'Scouler_willow',
#   'Western_flowering_dogwood',
#   'Western_hemlock',
#   'Western_red_cedar',
#   'ash_tree',
#   'bigleaf_maple',
#   'bitter_cherry',
#   'black_cottonwood',
#   'black_hawthorn',
#   'cascara',
#   'grand_fir',
#   'quaking_aspen',
#   'red_alder',
#   'rigid_willow'],
#  20,
#  2897,
#  724)

# %%
learn = cnn_learner(data, models.resnet50, metrics=[error_rate, accuracy], callback_fns=[partial(callbacks.EarlyStoppingCallback, monitor='accuracy', min_delta=0.01, patience=3)])

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.363817</td>
#       <td>2.526497</td>
#       <td>0.631215</td>
#       <td>0.368785</td>
#       <td>06:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.601106</td>
#       <td>1.977276</td>
#       <td>0.553867</td>
#       <td>0.446133</td>
#       <td>06:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.052850</td>
#       <td>1.788893</td>
#       <td>0.511050</td>
#       <td>0.488950</td>
#       <td>06:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.666577</td>
#       <td>1.746676</td>
#       <td>0.500000</td>
#       <td>0.500000</td>
#       <td>06:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# ## Save Model and Unfreeze Layers

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# ## Train All Layers

# %%
learn.fit_one_cycle(150, max_lr=slice(1e-6,1e-3))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='150', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.67% [4/150 32:14<19:36:34]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.399952</td>
#       <td>1.730941</td>
#       <td>0.498619</td>
#       <td>0.501381</td>
#       <td>07:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.348138</td>
#       <td>1.719015</td>
#       <td>0.502762</td>
#       <td>0.497238</td>
#       <td>08:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.304687</td>
#       <td>1.715902</td>
#       <td>0.495856</td>
#       <td>0.504144</td>
#       <td>08:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.269370</td>
#       <td>1.705840</td>
#       <td>0.494475</td>
#       <td>0.505525</td>
#       <td>08:07</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12' class='' max='12', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12/12 00:32<00:00]
#     </div>
# Epoch 4: early stopping
