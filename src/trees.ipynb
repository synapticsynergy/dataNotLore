# %% [markdown]
# # Fastai Experimentation

# %% [markdown]
# This notebook is intended to be used after running the google image scraper in this repo. To get started follow the README.md in this repo, then come back after all the csv files have been generated, labeled, and saved in the data_csv directory.

# %%
from fastai.vision import *
import os
path = Path(f'../data_csv')

# %% [markdown]
# ### Define Experiment
# Running this cell will save the images and any saved models in a directory with the experiments name.

# %%
experiment = 'tree'

# %%
dest_path = Path(f'../data')
img_path = dest_path/experiment

# %% [markdown]
# ## Download images per class
# The google scraper will save the csv files labeled by the classes you want to train. These csv files will be nested in a directory with the labeled classname. For example:
# ```
# data_csv/
#     ash_tree/
#         ash_tree.csv
#     bigleaf_maple/
#         bigleaf_maple.csv
#         ...
# ```
# The images will be saved in a data directory nested under experiment name and class name:
# ```
# data/
#     trees/
#         ash_tree/
#             *.jpeg
# ```

# %%
for folder in os.listdir('../data_csv'):
    file = path/folder/os.listdir(f'../data_csv/{folder}')[0]
    dest = img_path/folder
    dest.mkdir(parents=True, exist_ok=True)
    print(folder, '   ',file, ' dest', dest)
    download_images(file, dest, max_pics=200)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /home/blakedanson/anaconda3/envs/fastai/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Verify Images can be Trained

# %%
classes = os.listdir(f'../data/{experiment}')
for c in classes:
    print(c)
    verify_images(img_path/c, delete=True, max_size=500)

# %% [markdown]
# ## Create ImageDataBunch for Training

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(img_path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# ## Show Classes to be Trained

# %%
data.classes
# Out:
# ['Douglas-fir',
#  'Oregon_white_oak',
#  'Pacific_madrone',
#  'Pacific_willow',
#  'Pacific_yew',
#  'Ponderosa_pine',
#  'Scouler_willow',
#  'Western_flowering_dogwood',
#  'Western_hemlock',
#  'Western_red_cedar',
#  'ash_tree',
#  'bigleaf_maple',
#  'bitter_cherry',
#  'black_cottonwood',
#  'black_hawthorn',
#  'cascara',
#  'grand_fir',
#  'quaking_aspen',
#  'red_alder',
#  'rigid_willow']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Douglas-fir',
#   'Oregon_white_oak',
#   'Pacific_madrone',
#   'Pacific_willow',
#   'Pacific_yew',
#   'Ponderosa_pine',
#   'Scouler_willow',
#   'Western_flowering_dogwood',
#   'Western_hemlock',
#   'Western_red_cedar',
#   'ash_tree',
#   'bigleaf_maple',
#   'bitter_cherry',
#   'black_cottonwood',
#   'black_hawthorn',
#   'cascara',
#   'grand_fir',
#   'quaking_aspen',
#   'red_alder',
#   'rigid_willow'],
#  20,
#  2905,
#  726)

# %%
learn = cnn_learner(data, models.resnet50, metrics=[error_rate, accuracy], callback_fns=[partial(callbacks.EarlyStoppingCallback, monitor='accuracy', min_delta=0.01, patience=5)])

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr=3e-3

# %%
learn.fit_one_cycle(4, max_lr=slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.460647</td>
#       <td>2.585419</td>
#       <td>0.636364</td>
#       <td>0.363636</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.628470</td>
#       <td>2.029655</td>
#       <td>0.567493</td>
#       <td>0.432507</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.093420</td>
#       <td>1.864160</td>
#       <td>0.555096</td>
#       <td>0.444904</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.701203</td>
#       <td>1.796840</td>
#       <td>0.545455</td>
#       <td>0.454545</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# ## Save Model and Unfreeze Layers

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
starting_lr = 3e-4

# %% [markdown]
# ## Train All Layers

# %%
learn.fit_one_cycle(150, max_lr=slice(starting_lr,lr/10))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='150', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.33% [14/150 05:57<57:49]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.187274</td>
#       <td>1.918261</td>
#       <td>0.418733</td>
#       <td>0.581267</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.143300</td>
#       <td>1.883221</td>
#       <td>0.417355</td>
#       <td>0.582645</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.125628</td>
#       <td>1.880268</td>
#       <td>0.406336</td>
#       <td>0.593664</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.108959</td>
#       <td>1.858256</td>
#       <td>0.398072</td>
#       <td>0.601928</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.093423</td>
#       <td>1.850509</td>
#       <td>0.407714</td>
#       <td>0.592287</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.080323</td>
#       <td>1.887070</td>
#       <td>0.403581</td>
#       <td>0.596419</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.077488</td>
#       <td>1.868687</td>
#       <td>0.398072</td>
#       <td>0.601928</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.075504</td>
#       <td>1.889362</td>
#       <td>0.406336</td>
#       <td>0.593664</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.077323</td>
#       <td>1.891708</td>
#       <td>0.395317</td>
#       <td>0.604683</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.079804</td>
#       <td>1.978629</td>
#       <td>0.406336</td>
#       <td>0.593664</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.096887</td>
#       <td>2.027951</td>
#       <td>0.418733</td>
#       <td>0.581267</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.094701</td>
#       <td>2.061547</td>
#       <td>0.422865</td>
#       <td>0.577135</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.108155</td>
#       <td>2.042213</td>
#       <td>0.417355</td>
#       <td>0.582645</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.128386</td>
#       <td>2.167221</td>
#       <td>0.420110</td>
#       <td>0.579890</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12' class='' max='12', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12/12 00:02<00:00]
#     </div>
# Epoch 14: early stopping
